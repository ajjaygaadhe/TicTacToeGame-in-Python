# %%
#####TIC TAC TOE Game#############AJJAY GAADHE###############################
flag=0
list2=[]
list1=['0','1','2','3','4','5','6','7','8']
d={'player1':'X','player2':'O'} ###Assigning Symbol for player 1 and Player 2
checkval=1

def check(pos):
    if pos in list2:
         print('invalid option Try Again')
        checkval=0
        return checkval
                
    else:
        #list2.append(pos)
        checkval=1 
        return checkval
def player1():
    pos_X= int(input('Player one select position: '))
    if pos_X >=9:
        print ("Invalid Input position")
    checkval=check(pos_X)
    #print(f'checkvalue is {checkval}')
    if checkval==0:
        flag=0
        flag=player1()
        return flag
    else:
        list2.append(pos_X)
        list1[pos_X]=d['player1']
        print(f'{list1[6]} || {list1[7]} || {list1[8]}')
        print(f'{list1[3]} || {list1[4]} || {list1[5]}')
        print(f'{list1[0]} || {list1[1]} || {list1[2]}')
        flag=1
        print(list2)
        if (list1[1]==list1[2]==list1[0] or list1[4]==list1[5]==list1[3] 
            or list1[7]==list1[8]==list1[6]or list1[1]==list1[4]==list1[7] 
            or list1[5]==list1[2]==list1[8] or list1[3]==list1[6]==list1[0]
            or list1[0]==list1[4]==list1[8] or list1[6]==list1[4]==list1[2]):
            print('Player 1 won')
            flag=3
        return flag
        
        
def player2():
    pos_O= int(input('Player two select position: '))
    if pos_O >=9:
        print ("Invalid Input position")
    checkval=check(pos_O)
    if checkval==0:
        flag=player2()
        return flag
    else:
        
        list2.append(pos_O)
        list1[pos_O]=d['player2']
        print(f'{list1[6]} || {list1[7]} || {list1[8]}')
        print(f'{list1[3]} || {list1[4]} || {list1[5]}')
        print(f'{list1[0]} || {list1[1]} || {list1[2]}')
        flag=0
        print(list2)
        
        if (list1[1]==list1[2]==list1[0] or list1[4]==list1[5]==list1[3] 
            or list1[7]==list1[8]==list1[6]or list1[1]==list1[4]==list1[7] 
            or list1[5]==list1[2]==list1[8] or list1[3]==list1[6]==list1[0]
            or list1[0]==list1[4]==list1[8] or list1[6]==list1[4]==list1[2]):
            print('Player 2 won')
            flag=3
        
        return flag


for count in range(1,10):
    if flag==0:
        flag=player1()
        print(f'value of flag is : {flag}')
        if flag==3:
            break
       # print('return')
    elif flag==1:
        flag=player2()
        print(f'value of flag is : {flag}')
        if flag==3:
            break

#for count in range(0,9):
   # if flag==0:
         #player1()
        #pos_X= int(input('Player one select position: '))
        #list2.append(pos_X)
       # check(pos_X)
       # if check==0:
           #player1()
       # else:
        #    list2.append(pos_X)
        #    list1[pos_X]=d['player1']
        #    print(f'{list1[6]} || {list1[7]} || {list1[8]}')
         #   print(f'{list1[3]} || {list1[4]} || {list1[5]}')
         #   print(f'{list1[0]} || {list1[1]} || {list1[2]}')
          #  flag=1
          #  print(list2)
    #elif flag==1:
        #player2()
        #pos_O= int(input('Player two select position: '))
        #check(pos_O)
        #if check==0:
          #  continue
        #else:
            #list2.append(pos_O)
            #list1[pos_O]=d['player2']
            #print(f'{list1[6]} || {list1[7]} || {list1[8]}')
            #print(f'{list1[3]} || {list1[4]} || {list1[5]}')
            #print(f'{list1[0]} || {list1[1]} || {list1[2]}')
            #flag=0
           # print(list2)
# Out:
# Player one select position: 8
# 6 || 7 || X
# 3 || 4 || 5
# 0 || 1 || 2
# [8]
# value of flag is : 1
# Player two select position: 9
# Invalid Input position
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-767f5dd4c283> in <module>
#      79        # print('return')
#      80     elif flag==1:
# ---> 81         flag=player2()
#      82         print(f'value of flag is : {flag}')
#      83         if flag==3:
#
# <ipython-input-6-767f5dd4c283> in player2()
#      54
#      55         list2.append(pos_O)
# ---> 56         list1[pos_O]=d['player2']
#      57         print(f'{list1[6]} || {list1[7]} || {list1[8]}')
#      58         print(f'{list1[3]} || {list1[4]} || {list1[5]}')
#
# IndexError: list assignment index out of range
